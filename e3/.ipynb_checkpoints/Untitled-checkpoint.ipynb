# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
import sys
from pykalman import KalmanFilter

# reminder to possibly edit the csv argument

cpu_data = pd.read_csv("sysinfo.csv")
cpu_data["timestamp"] = pd.to_datetime(cpu_data["timestamp"])
plt.figure(figsize=(12, 4))
plt.plot(cpu_data['timestamp'], cpu_data['temperature'], 'b.', alpha=0.5)

loess_smoothed = lowess(cpu_data['temperature'], 
	cpu_data['timestamp'], frac=.005)
plt.plot(cpu_data['timestamp'], loess_smoothed[:, 1], 'r-')
plt.show() # maybe easier for testing
# plt.savefig('cpu.svg') # for final submission

# %%
kalman_data = cpu_data[['temperature', 'cpu_percent', 'sys_load_1', 'fan_rpm']]

initial_state = kalman_data.iloc[0]
observation_covariance = np.diag([0, 0, 0, 0]) ** 2 # TODO: shouldn't be zero
transition_covariance = np.diag([0, 0, 0, 0]) ** 2 # TODO: shouldn't be zero
transition = [[0.97, 0.5, 0.2, -0.001,]
             [0.1, 0.4, 2.2, 1]
             [0.95, 1, 1, 1]
             [1, 1, 1, 1]]

kf = KalmanFilter(initial_state_nean=initial_state,
                 initial_state_covariance=observation_covariance,
                 observation_covariance=observation_covariance,
                 transition_covariance=transition_covariance)
kalman_smoothed, state_cov_ = kf.smooth(kalman_data)
plt.plot(cpu_data['timestamp'], kalman_smoothed[:, 0], 'g-')
# Out:
# <>:7: SyntaxWarning: list indices must be integers or slices, not float; perhaps you missed a comma?
# <>:7: SyntaxWarning: list indices must be integers or slices, not float; perhaps you missed a comma?
# <ipython-input-29-c66e4eed165c>:7: SyntaxWarning: list indices must be integers or slices, not float; perhaps you missed a comma?
#   [0.1],[0.4],[2.2],[1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c66e4eed165c> in <module>
#       5 transition_covariance = np.diag([0, 0, 0, 0]) ** 2 # TODO: shouldn't be zero
#       6 transition = [[0.97],[0.5],[0.2],[-0.001],
# ----> 7              [0.1],[0.4],[2.2],[1]
#       8              [0.95],[1],[1],[1]
#       9              [1],[1],[1],[1]]
#
# TypeError: list indices must be integers or slices, not float
